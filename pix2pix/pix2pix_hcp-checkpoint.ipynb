# %%
import torch
torch. __version__
# Out:
# '1.9.0+cu111'

# %%
import torchvision
torchvision. __version__
# Out:
# '0.10.0+cu111'

# %%
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torchvision
import functools
import torchvision.models as models
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torch.optim as optim
from torchvision import transforms
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
from torch.autograd import Variable
from torchvision.utils import save_image
from torch.utils.tensorboard import SummaryWriter
from sklearn.model_selection import train_test_split
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset
import time
from sklearn.model_selection import train_test_split
import pylab as pl
from IPython import display
import logging
import os
import shutil
import sys
import torch.nn as nn
import tempfile
import random
import numpy as np
from tqdm import trange
import matplotlib.pyplot as plt
import torch
from urllib.request import urlretrieve
import gzip
from PIL import Image
import pathlib
from pathlib import Path
import pandas as pd

# %%
# !nvidia-smi
# Out:
# Fri Nov 10 11:19:44 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti      Off| 00000000:02:00.0 Off |                  N/A |
# | 27%   30C    P8               21W / 260W|      0MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import tarfile
# Replace 'your_file.tar.gz' with the actual filename of your tarball.
tarball_file = '/home/e.antipushina/fc.tar.gz'

# Replace 'extract_folder' with the path to the folder where you want to extract the files.
extract_folder = './hcp_rest_and_motor/'

# Create the extraction folder if it doesn't exist
if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

# Extract the tarball to the specified folder
with tarfile.open(tarball_file, 'r:gz') as tar:
    tar.extractall(path=extract_folder)

print(f"Successfully extracted {tarball_file} to {extract_folder}")
# Out:
# Successfully extracted /home/e.antipushina/fc.tar.gz to ./hcp_rest_and_motor/

# %%
data_directory  = './beegfs/home/ruslan.kalimullin/Image_to_image/data_77'

# %%
os.listdir(data_directory)
# Out:
# ['737960_tfMRI_LANGUAGE_LR.csv',
#  '108020_tfMRI_LANGUAGE_LR.csv',
#  '198855_rfMRI_REST1_LR.csv',
#  '163129_rfMRI_REST1_LR.csv',
#  '397154_tfMRI_LANGUAGE_LR.csv',
#  '146735_tfMRI_LANGUAGE_LR.csv',
#  '144428_tfMRI_MOTOR_LR.csv',
#  '436239_rfMRI_REST1_LR.csv',
#  '188448_rfMRI_REST1_LR.csv',
#  '166438_tfMRI_MOTOR_LR.csv',
#  '101915_tfMRI_MOTOR_LR.csv',
#  '135124_rfMRI_REST1_LR.csv',
#  '414229_tfMRI_MOTOR_LR.csv',
#  '160830_rfMRI_REST1_LR.csv',
#  '341834_tfMRI_LANGUAGE_LR.csv',
#  '198350_rfMRI_REST1_LR.csv',
#  '320826_tfMRI_LANGUAGE_LR.csv',
#  '100610_tfMRI_MOTOR_LR.csv',
#  '688569_tfMRI_LANGUAGE_LR.csv',
#  '110007_tfMRI_MOTOR_LR.csv',
#  '101410_tfMRI_MOTOR_LR.csv',
#  '101107_rfMRI_REST1_LR.csv',
#  '165638_rfMRI_REST1_LR.csv',
#  '114924_tfMRI_LANGUAGE_LR.csv',
#  '588565_rfMRI_REST1_LR.csv',
#  '391748_tfMRI_LANGUAGE_LR.csv',
#  '118124_rfMRI_REST1_LR.csv',
#  '177746_tfMRI_MOTOR_LR.csv',
#  '204420_tfMRI_MOTOR_LR.csv',
#  '497865_rfMRI_REST1_LR.csv',
#  '203923_tfMRI_MOTOR_LR.csv',
#  '153833_tfMRI_LANGUAGE_LR.csv',
#  '114823_tfMRI_LANGUAGE_LR.csv',
#  '155938_tfMRI_LANGUAGE_LR.csv',
#  '239944_tfMRI_LANGUAGE_LR.csv',
#  '111514_tfMRI_LANGUAGE_LR.csv',
#  '143224_tfMRI_MOTOR_LR.csv',
#  '304020_rfMRI_REST1_LR.csv',
#  '268749_tfMRI_MOTOR_LR.csv',
#  '709551_tfMRI_LANGUAGE_LR.csv',
#  '393247_tfMRI_MOTOR_LR.csv',
#  '124624_rfMRI_REST1_LR.csv',
#  '342129_tfMRI_MOTOR_LR.csv',
#  '213421_rfMRI_REST1_LR.csv',
#  '201515_tfMRI_MOTOR_LR.csv',
#  '143224_rfMRI_REST1_LR.csv',
#  '280739_tfMRI_MOTOR_LR.csv',
#  '123521_tfMRI_LANGUAGE_LR.csv',
#  '151829_tfMRI_MOTOR_LR.csv',
#  '654552_tfMRI_MOTOR_LR.csv',
#  '166438_tfMRI_LANGUAGE_LR.csv',
#  '419239_tfMRI_LANGUAGE_LR.csv',
#  '665254_tfMRI_MOTOR_LR.csv',
#  '135730_tfMRI_MOTOR_LR.csv',
#  '150726_tfMRI_LANGUAGE_LR.csv',
#  '523032_tfMRI_MOTOR_LR.csv',
#  '176542_rfMRI_REST1_LR.csv',
#  '138130_rfMRI_REST1_LR.csv',
#  '588565_tfMRI_LANGUAGE_LR.csv',
#  '208024_tfMRI_MOTOR_LR.csv',
#  '168139_rfMRI_REST1_LR.csv',
#  '618952_rfMRI_REST1_LR.csv',
#  '395756_rfMRI_REST1_LR.csv',
#  '128026_tfMRI_MOTOR_LR.csv',
#  '214726_rfMRI_REST1_LR.csv',
#  '178748_rfMRI_REST1_LR.csv',
#  '164636_tfMRI_LANGUAGE_LR.csv',
#  '217126_tfMRI_MOTOR_LR.csv',
#  '168947_rfMRI_REST1_LR.csv',
#  '113316_rfMRI_REST1_LR.csv',
#  '139637_tfMRI_LANGUAGE_LR.csv',
#  '137633_tfMRI_LANGUAGE_LR.csv',
#  '473952_rfMRI_REST1_LR.csv',
#  '146836_tfMRI_LANGUAGE_LR.csv',
#  '322224_tfMRI_LANGUAGE_LR.csv',
#  '158540_rfMRI_REST1_LR.csv',
#  '368753_tfMRI_LANGUAGE_LR.csv',
#  '295146_tfMRI_MOTOR_LR.csv',
#  '172635_rfMRI_REST1_LR.csv',
#  '573451_tfMRI_LANGUAGE_LR.csv',
#  '185846_tfMRI_MOTOR_LR.csv',
#  '204622_rfMRI_REST1_LR.csv',
#  '378756_rfMRI_REST1_LR.csv',
#  '188347_rfMRI_REST1_LR.csv',
#  '700634_tfMRI_LANGUAGE_LR.csv',
#  '680250_tfMRI_MOTOR_LR.csv',
#  '377451_rfMRI_REST1_LR.csv',
#  '175035_tfMRI_LANGUAGE_LR.csv',
#  '188347_tfMRI_LANGUAGE_LR.csv',
#  '172029_tfMRI_LANGUAGE_LR.csv',
#  '176441_rfMRI_REST1_LR.csv',
#  '656657_tfMRI_MOTOR_LR.csv',
#  '210617_tfMRI_LANGUAGE_LR.csv',
#  '211720_tfMRI_MOTOR_LR.csv',
#  '181131_tfMRI_MOTOR_LR.csv',
#  '110613_tfMRI_MOTOR_LR.csv',
#  '185341_tfMRI_LANGUAGE_LR.csv',
#  '135124_tfMRI_LANGUAGE_LR.csv',
#  '208024_tfMRI_LANGUAGE_LR.csv',
#  '316835_tfMRI_LANGUAGE_LR.csv',
#  '614439_tfMRI_MOTOR_LR.csv',
#  '151021_tfMRI_LANGUAGE_LR.csv',
#  '559457_tfMRI_MOTOR_LR.csv',
#  '181232_tfMRI_LANGUAGE_LR.csv',
#  '117324_rfMRI_REST1_LR.csv',
#  '365343_tfMRI_LANGUAGE_LR.csv',
#  '412528_rfMRI_REST1_LR.csv',
#  '172029_rfMRI_REST1_LR.csv',
#  '132017_tfMRI_LANGUAGE_LR.csv',
#  '622236_rfMRI_REST1_LR.csv',
#  '168341_tfMRI_MOTOR_LR.csv',
#  '111312_tfMRI_LANGUAGE_LR.csv',
#  '559457_rfMRI_REST1_LR.csv',
#  '352738_rfMRI_REST1_LR.csv',
#  '141422_tfMRI_MOTOR_LR.csv',
#  '445543_tfMRI_MOTOR_LR.csv',
#  '111514_tfMRI_MOTOR_LR.csv',
#  '138231_rfMRI_REST1_LR.csv',
#  '155635_rfMRI_REST1_LR.csv',
#  '138130_tfMRI_LANGUAGE_LR.csv',
#  '371843_rfMRI_REST1_LR.csv',
#  '314225_tfMRI_LANGUAGE_LR.csv',
#  '233326_tfMRI_LANGUAGE_LR.csv',
#  '206323_tfMRI_MOTOR_LR.csv',
#  '134223_tfMRI_MOTOR_LR.csv',
#  '139637_rfMRI_REST1_LR.csv',
#  '181636_rfMRI_REST1_LR.csv',
#  '189349_tfMRI_MOTOR_LR.csv',
#  '199352_rfMRI_REST1_LR.csv',
#  '101309_tfMRI_MOTOR_LR.csv',
#  '510326_rfMRI_REST1_LR.csv',
#  '121618_rfMRI_REST1_LR.csv',
#  '104416_tfMRI_LANGUAGE_LR.csv',
#  '187547_rfMRI_REST1_LR.csv',
#  '206727_tfMRI_MOTOR_LR.csv',
#  '720337_tfMRI_LANGUAGE_LR.csv',
#  '200917_rfMRI_REST1_LR.csv',
#  '116524_rfMRI_REST1_LR.csv',
#  '183034_tfMRI_LANGUAGE_LR.csv',
#  '194746_tfMRI_MOTOR_LR.csv',
#  '250932_tfMRI_LANGUAGE_LR.csv',
#  '555954_tfMRI_LANGUAGE_LR.csv',
#  '214221_tfMRI_LANGUAGE_LR.csv',
#  '192035_tfMRI_LANGUAGE_LR.csv',
#  '106319_tfMRI_MOTOR_LR.csv',
#  '233326_tfMRI_MOTOR_LR.csv',
#  '180735_rfMRI_REST1_LR.csv',
#  '180836_tfMRI_LANGUAGE_LR.csv',
#  '115825_tfMRI_LANGUAGE_LR.csv',
#  '317332_rfMRI_REST1_LR.csv',
#  '143426_tfMRI_MOTOR_LR.csv',
#  '164939_tfMRI_LANGUAGE_LR.csv',
#  '127226_tfMRI_MOTOR_LR.csv',
#  '112314_rfMRI_REST1_LR.csv',
#  '390645_rfMRI_REST1_LR.csv',
#  '680452_tfMRI_MOTOR_LR.csv',
#  '189652_tfMRI_MOTOR_LR.csv',
#  '680452_tfMRI_LANGUAGE_LR.csv',
#  '316835_tfMRI_MOTOR_LR.csv',
#  '103515_rfMRI_REST1_LR.csv',
#  '167440_tfMRI_LANGUAGE_LR.csv',
#  '406836_tfMRI_LANGUAGE_LR.csv',
#  '378756_tfMRI_LANGUAGE_LR.csv',
#  '102513_tfMRI_MOTOR_LR.csv',
#  '195849_tfMRI_MOTOR_LR.csv',
#  '204420_tfMRI_LANGUAGE_LR.csv',
#  '211922_tfMRI_LANGUAGE_LR.csv',
#  '613538_tfMRI_LANGUAGE_LR.csv',
#  '102109_tfMRI_LANGUAGE_LR.csv',
#  '114419_tfMRI_LANGUAGE_LR.csv',
#  '108020_rfMRI_REST1_LR.csv',
#  '172130_tfMRI_LANGUAGE_LR.csv',
#  '397861_rfMRI_REST1_LR.csv',
#  '463040_tfMRI_LANGUAGE_LR.csv',
#  '123824_tfMRI_LANGUAGE_LR.csv',
#  '677968_rfMRI_REST1_LR.csv',
#  '424939_tfMRI_LANGUAGE_LR.csv',
#  '130114_rfMRI_REST1_LR.csv',
#  '268850_tfMRI_MOTOR_LR.csv',
#  '371843_tfMRI_LANGUAGE_LR.csv',
#  '117324_tfMRI_LANGUAGE_LR.csv',
#  '202719_tfMRI_MOTOR_LR.csv',
#  '198653_rfMRI_REST1_LR.csv',
#  '406836_tfMRI_MOTOR_LR.csv',
#  '171734_tfMRI_LANGUAGE_LR.csv',
#  '121921_rfMRI_REST1_LR.csv',
#  '512835_tfMRI_LANGUAGE_LR.csv',
#  '316633_tfMRI_MOTOR_LR.csv',
#  '308331_tfMRI_LANGUAGE_LR.csv',
#  '163331_tfMRI_MOTOR_LR.csv',
#  '615744_tfMRI_LANGUAGE_LR.csv',
#  '106319_tfMRI_LANGUAGE_LR.csv',
#  '635245_rfMRI_REST1_LR.csv',
#  '139839_tfMRI_LANGUAGE_LR.csv',
#  '379657_tfMRI_MOTOR_LR.csv',
#  '728454_tfMRI_MOTOR_LR.csv',
#  '249947_tfMRI_MOTOR_LR.csv',
#  '638049_tfMRI_LANGUAGE_LR.csv',
#  '101915_rfMRI_REST1_LR.csv',
#  '263436_tfMRI_LANGUAGE_LR.csv',
#  '110411_tfMRI_LANGUAGE_LR.csv',
#  '616645_tfMRI_MOTOR_LR.csv',
#  '168240_tfMRI_LANGUAGE_LR.csv',
#  '194645_tfMRI_LANGUAGE_LR.csv',
#  '204218_tfMRI_LANGUAGE_LR.csv',
#  '148335_tfMRI_MOTOR_LR.csv',
#  '304727_rfMRI_REST1_LR.csv',
#  '168947_tfMRI_MOTOR_LR.csv',
#  '449753_rfMRI_REST1_LR.csv',
#  '210415_tfMRI_MOTOR_LR.csv',
#  '102311_tfMRI_LANGUAGE_LR.csv',
#  '147030_tfMRI_MOTOR_LR.csv',
#  '192843_rfMRI_REST1_LR.csv',
#  '510225_rfMRI_REST1_LR.csv',
#  '257946_tfMRI_LANGUAGE_LR.csv',
#  '469961_tfMRI_MOTOR_LR.csv',
#  '173435_tfMRI_MOTOR_LR.csv',
#  '524135_tfMRI_LANGUAGE_LR.csv',
#  '142828_tfMRI_LANGUAGE_LR.csv',
#  '206828_rfMRI_REST1_LR.csv',
#  '689470_tfMRI_MOTOR_LR.csv',
#  '144428_rfMRI_REST1_LR.csv',
#  '199453_tfMRI_MOTOR_LR.csv',
#  '136631_rfMRI_REST1_LR.csv',
#  '137128_tfMRI_LANGUAGE_LR.csv',
#  '566454_tfMRI_LANGUAGE_LR.csv',
#  '694362_tfMRI_LANGUAGE_LR.csv',
#  '153934_tfMRI_MOTOR_LR.csv',
#  '129937_tfMRI_MOTOR_LR.csv',
#  '299154_tfMRI_LANGUAGE_LR.csv',
#  '209935_tfMRI_MOTOR_LR.csv',
#  '224022_tfMRI_LANGUAGE_LR.csv',
#  '644044_tfMRI_MOTOR_LR.csv',
#  '397760_tfMRI_MOTOR_LR.csv',
#  '547046_tfMRI_LANGUAGE_LR.csv',
#  '126628_tfMRI_MOTOR_LR.csv',
#  '173334_tfMRI_MOTOR_LR.csv',
#  '106521_tfMRI_LANGUAGE_LR.csv',
#  '136732_tfMRI_MOTOR_LR.csv',
#  '728454_tfMRI_LANGUAGE_LR.csv',
#  '143830_tfMRI_LANGUAGE_LR.csv',
#  '573249_tfMRI_MOTOR_LR.csv',
#  '391748_tfMRI_MOTOR_LR.csv',
#  '128935_rfMRI_REST1_LR.csv',
#  '249947_tfMRI_LANGUAGE_LR.csv',
#  '125525_tfMRI_LANGUAGE_LR.csv',
#  '131924_tfMRI_MOTOR_LR.csv',
#  '194443_rfMRI_REST1_LR.csv',
#  '103212_tfMRI_MOTOR_LR.csv',
#  '387959_rfMRI_REST1_LR.csv',
#  '101107_tfMRI_LANGUAGE_LR.csv',
#  '114823_tfMRI_MOTOR_LR.csv',
#  '178243_tfMRI_LANGUAGE_LR.csv',
#  '734045_tfMRI_LANGUAGE_LR.csv',
#  '175439_tfMRI_LANGUAGE_LR.csv',
#  '194443_tfMRI_LANGUAGE_LR.csv',
#  '126426_rfMRI_REST1_LR.csv',
#  '284646_tfMRI_LANGUAGE_LR.csv',
#  '148335_rfMRI_REST1_LR.csv',
#  '158136_rfMRI_REST1_LR.csv',
#  '158843_rfMRI_REST1_LR.csv',
#  '206727_tfMRI_LANGUAGE_LR.csv',
#  '183034_tfMRI_MOTOR_LR.csv',
#  '134324_tfMRI_LANGUAGE_LR.csv',
#  '397154_rfMRI_REST1_LR.csv',
#  '155938_tfMRI_MOTOR_LR.csv',
#  '183337_rfMRI_REST1_LR.csv',
#  '305830_tfMRI_MOTOR_LR.csv',
#  '463040_tfMRI_MOTOR_LR.csv',
#  '151223_tfMRI_LANGUAGE_LR.csv',
#  '182032_tfMRI_MOTOR_LR.csv',
#  '199453_tfMRI_LANGUAGE_LR.csv',
#  '117122_rfMRI_REST1_LR.csv',
#  '100307_tfMRI_LANGUAGE_LR.csv',
#  '154229_tfMRI_MOTOR_LR.csv',
#  '725751_tfMRI_LANGUAGE_LR.csv',
#  '236130_rfMRI_REST1_LR.csv',
#  '115320_tfMRI_LANGUAGE_LR.csv',
#  '175338_tfMRI_MOTOR_LR.csv',
#  '140824_tfMRI_MOTOR_LR.csv',
#  '615441_tfMRI_LANGUAGE_LR.csv',
#  '744553_tfMRI_LANGUAGE_LR.csv',
#  '239944_tfMRI_MOTOR_LR.csv',
#  '147737_tfMRI_LANGUAGE_LR.csv',
#  '158540_tfMRI_LANGUAGE_LR.csv',
#  '594156_tfMRI_LANGUAGE_LR.csv',
#  '106521_rfMRI_REST1_LR.csv',
#  '213522_tfMRI_MOTOR_LR.csv',
#  '211619_tfMRI_LANGUAGE_LR.csv',
#  '110411_tfMRI_MOTOR_LR.csv',
#  '135225_tfMRI_MOTOR_LR.csv',
#  '106016_tfMRI_MOTOR_LR.csv',
#  '100307_tfMRI_MOTOR_LR.csv',
#  '214019_tfMRI_LANGUAGE_LR.csv',
#  '188145_rfMRI_REST1_LR.csv',
#  '732243_rfMRI_REST1_LR.csv',
#  '553344_tfMRI_LANGUAGE_LR.csv',
#  '113316_tfMRI_MOTOR_LR.csv',
#  '210617_rfMRI_REST1_LR.csv',
#  '548250_tfMRI_LANGUAGE_LR.csv',
#  '618952_tfMRI_LANGUAGE_LR.csv',
#  '467351_rfMRI_REST1_LR.csv',
#  '355239_rfMRI_REST1_LR.csv',
#  '210415_tfMRI_LANGUAGE_LR.csv',
#  '737960_rfMRI_REST1_LR.csv',
#  '147030_rfMRI_REST1_LR.csv',
#  '148133_rfMRI_REST1_LR.csv',
#  '141826_rfMRI_REST1_LR.csv',
#  '660951_tfMRI_LANGUAGE_LR.csv',
#  '473952_tfMRI_MOTOR_LR.csv',
#  '731140_rfMRI_REST1_LR.csv',
#  '208024_rfMRI_REST1_LR.csv',
#  '205119_tfMRI_MOTOR_LR.csv',
#  '731140_tfMRI_LANGUAGE_LR.csv',
#  '113215_rfMRI_REST1_LR.csv',
#  '165436_tfMRI_LANGUAGE_LR.csv',
#  '536647_tfMRI_MOTOR_LR.csv',
#  '330324_tfMRI_MOTOR_LR.csv',
#  '274542_rfMRI_REST1_LR.csv',
#  '329844_tfMRI_LANGUAGE_LR.csv',
#  '390645_tfMRI_MOTOR_LR.csv',
#  '654754_rfMRI_REST1_LR.csv',
#  '662551_rfMRI_REST1_LR.csv',
#  '205826_rfMRI_REST1_LR.csv',
#  '187345_tfMRI_MOTOR_LR.csv',
#  '728454_rfMRI_REST1_LR.csv',
#  '664757_tfMRI_MOTOR_LR.csv',
#  '135528_rfMRI_REST1_LR.csv',
#  '134223_tfMRI_LANGUAGE_LR.csv',
#  '103515_tfMRI_MOTOR_LR.csv',
#  '114419_rfMRI_REST1_LR.csv',
#  '599671_tfMRI_LANGUAGE_LR.csv',
#  '111211_tfMRI_MOTOR_LR.csv',
#  '634748_tfMRI_MOTOR_LR.csv',
#  '616645_rfMRI_REST1_LR.csv',
#  '275645_tfMRI_LANGUAGE_LR.csv',
#  '196346_tfMRI_MOTOR_LR.csv',
#  '311320_tfMRI_LANGUAGE_LR.csv',
#  '120515_rfMRI_REST1_LR.csv',
#  '150524_tfMRI_LANGUAGE_LR.csv',
#  '531536_tfMRI_MOTOR_LR.csv',
#  '161731_tfMRI_LANGUAGE_LR.csv',
#  '688569_rfMRI_REST1_LR.csv',
#  '727553_tfMRI_MOTOR_LR.csv',
#  '103010_rfMRI_REST1_LR.csv',
#  '381038_tfMRI_LANGUAGE_LR.csv',
#  '156536_rfMRI_REST1_LR.csv',
#  '567052_rfMRI_REST1_LR.csv',
#  '188145_tfMRI_LANGUAGE_LR.csv',
#  '604537_tfMRI_LANGUAGE_LR.csv',
#  '155635_tfMRI_MOTOR_LR.csv',
#  '131419_tfMRI_LANGUAGE_LR.csv',
#  '558657_rfMRI_REST1_LR.csv',
#  '702133_rfMRI_REST1_LR.csv',
#  '192136_rfMRI_REST1_LR.csv',
#  '486759_tfMRI_MOTOR_LR.csv',
#  '130720_rfMRI_REST1_LR.csv',
#  '107725_tfMRI_LANGUAGE_LR.csv',
#  '339847_rfMRI_REST1_LR.csv',
#  '378857_tfMRI_LANGUAGE_LR.csv',
#  '461743_rfMRI_REST1_LR.csv',
#  '118831_tfMRI_LANGUAGE_LR.csv',
#  '406836_rfMRI_REST1_LR.csv',
#  '173334_rfMRI_REST1_LR.csv',
#  '172433_tfMRI_LANGUAGE_LR.csv',
#  '580751_tfMRI_LANGUAGE_LR.csv',
#  '727553_rfMRI_REST1_LR.csv',
#  '112314_tfMRI_MOTOR_LR.csv',
#  '180533_tfMRI_MOTOR_LR.csv',
#  '553344_tfMRI_MOTOR_LR.csv',
#  '657659_tfMRI_LANGUAGE_LR.csv',
#  '219231_tfMRI_MOTOR_LR.csv',
#  '152427_rfMRI_REST1_LR.csv',
#  '203418_tfMRI_LANGUAGE_LR.csv',
#  '165032_rfMRI_REST1_LR.csv',
#  '148840_tfMRI_LANGUAGE_LR.csv',
#  '194645_rfMRI_REST1_LR.csv',
#  '201515_rfMRI_REST1_LR.csv',
#  '572045_tfMRI_LANGUAGE_LR.csv',
#  '156637_rfMRI_REST1_LR.csv',
#  '209834_rfMRI_REST1_LR.csv',
#  '286650_tfMRI_MOTOR_LR.csv',
#  '429040_rfMRI_REST1_LR.csv',
#  '122620_tfMRI_MOTOR_LR.csv',
#  '644044_rfMRI_REST1_LR.csv',
#  '192843_tfMRI_LANGUAGE_LR.csv',
#  '164636_rfMRI_REST1_LR.csv',
#  '196750_rfMRI_REST1_LR.csv',
#  '196346_rfMRI_REST1_LR.csv',
#  '151526_tfMRI_MOTOR_LR.csv',
#  '635245_tfMRI_MOTOR_LR.csv',
#  '322224_tfMRI_MOTOR_LR.csv',
#  '727654_tfMRI_LANGUAGE_LR.csv',
#  '189652_rfMRI_REST1_LR.csv',
#  '124624_tfMRI_MOTOR_LR.csv',
#  '205220_tfMRI_MOTOR_LR.csv',
#  '668361_tfMRI_MOTOR_LR.csv',
#  '127630_tfMRI_LANGUAGE_LR.csv',
#  '156536_tfMRI_LANGUAGE_LR.csv',
#  '672756_rfMRI_REST1_LR.csv',
#  '102816_tfMRI_MOTOR_LR.csv',
#  '308331_tfMRI_MOTOR_LR.csv',
#  '622236_tfMRI_LANGUAGE_LR.csv',
#  '352132_tfMRI_LANGUAGE_LR.csv',
#  '573451_rfMRI_REST1_LR.csv',
#  '175237_rfMRI_REST1_LR.csv',
#  '168947_tfMRI_LANGUAGE_LR.csv',
#  '570243_rfMRI_REST1_LR.csv',
#  '146937_tfMRI_MOTOR_LR.csv',
#  '206727_rfMRI_REST1_LR.csv',
#  '104820_tfMRI_LANGUAGE_LR.csv',
#  '618952_tfMRI_MOTOR_LR.csv',
#  '180230_tfMRI_MOTOR_LR.csv',
#  '724446_tfMRI_MOTOR_LR.csv',
#  '469961_tfMRI_LANGUAGE_LR.csv',
#  '559053_rfMRI_REST1_LR.csv',
#  '119732_tfMRI_MOTOR_LR.csv',
#  '237334_tfMRI_LANGUAGE_LR.csv',
#  '419239_tfMRI_MOTOR_LR.csv',
#  '192237_rfMRI_REST1_LR.csv',
#  '113619_tfMRI_MOTOR_LR.csv',
#  '555348_tfMRI_MOTOR_LR.csv',
#  '680250_rfMRI_REST1_LR.csv',
#  '689470_rfMRI_REST1_LR.csv',
#  '352738_tfMRI_MOTOR_LR.csv',
#  '133019_tfMRI_LANGUAGE_LR.csv',
#  '128632_tfMRI_LANGUAGE_LR.csv',
#  '138837_rfMRI_REST1_LR.csv',
#  '113215_tfMRI_LANGUAGE_LR.csv',
#  '180533_rfMRI_REST1_LR.csv',
#  '517239_rfMRI_REST1_LR.csv',
#  '579867_rfMRI_REST1_LR.csv',
#  '173940_rfMRI_REST1_LR.csv',
#  '308129_tfMRI_LANGUAGE_LR.csv',
#  '140824_rfMRI_REST1_LR.csv',
#  '724446_tfMRI_LANGUAGE_LR.csv',
#  '153227_tfMRI_LANGUAGE_LR.csv',
#  '366042_tfMRI_LANGUAGE_LR.csv',
#  '176441_tfMRI_MOTOR_LR.csv',
#  '172332_rfMRI_REST1_LR.csv',
#  '239136_tfMRI_LANGUAGE_LR.csv',
#  '448347_tfMRI_MOTOR_LR.csv',
#  '162228_tfMRI_LANGUAGE_LR.csv',
#  '126426_tfMRI_MOTOR_LR.csv',
#  '330324_rfMRI_REST1_LR.csv',
#  '310621_tfMRI_MOTOR_LR.csv',
#  '205826_tfMRI_MOTOR_LR.csv',
#  '162228_rfMRI_REST1_LR.csv',
#  '287248_rfMRI_REST1_LR.csv',
#  '353740_rfMRI_REST1_LR.csv',
#  '146432_rfMRI_REST1_LR.csv',
#  '171734_rfMRI_REST1_LR.csv',
#  '118932_rfMRI_REST1_LR.csv',
#  '193239_tfMRI_MOTOR_LR.csv',
#  '151829_tfMRI_LANGUAGE_LR.csv',
#  '308129_rfMRI_REST1_LR.csv',
#  '541640_rfMRI_REST1_LR.csv',
#  '146432_tfMRI_LANGUAGE_LR.csv',
#  '285345_tfMRI_MOTOR_LR.csv',
#  '211720_tfMRI_LANGUAGE_LR.csv',
#  '178849_tfMRI_MOTOR_LR.csv',
#  '115017_tfMRI_LANGUAGE_LR.csv',
#  '158843_tfMRI_LANGUAGE_LR.csv',
#  '729254_rfMRI_REST1_LR.csv',
#  '289555_tfMRI_MOTOR_LR.csv',
#  '115724_tfMRI_MOTOR_LR.csv',
#  '195849_rfMRI_REST1_LR.csv',
#  '154431_tfMRI_MOTOR_LR.csv',
#  '114924_rfMRI_REST1_LR.csv',
#  '274542_tfMRI_LANGUAGE_LR.csv',
#  '183034_rfMRI_REST1_LR.csv',
#  '167440_rfMRI_REST1_LR.csv',
#  '589567_tfMRI_MOTOR_LR.csv',
#  '419239_rfMRI_REST1_LR.csv',
#  '178243_rfMRI_REST1_LR.csv',
#  '114823_rfMRI_REST1_LR.csv',
#  '161731_rfMRI_REST1_LR.csv',
#  '310621_rfMRI_REST1_LR.csv',
#  '623844_tfMRI_LANGUAGE_LR.csv',
#  '143426_rfMRI_REST1_LR.csv',
#  '536647_tfMRI_LANGUAGE_LR.csv',
#  '245333_rfMRI_REST1_LR.csv',
#  '198451_tfMRI_LANGUAGE_LR.csv',
#  '154330_tfMRI_LANGUAGE_LR.csv',
#  '626648_rfMRI_REST1_LR.csv',
#  '589567_tfMRI_LANGUAGE_LR.csv',
#  '680250_tfMRI_LANGUAGE_LR.csv',
#  '171330_tfMRI_LANGUAGE_LR.csv',
#  '199352_tfMRI_MOTOR_LR.csv',
#  '185038_tfMRI_MOTOR_LR.csv',
#  '139637_tfMRI_MOTOR_LR.csv',
#  '108323_tfMRI_MOTOR_LR.csv',
#  '720337_tfMRI_MOTOR_LR.csv',
#  '171330_rfMRI_REST1_LR.csv',
#  '103010_tfMRI_LANGUAGE_LR.csv',
#  '679568_tfMRI_LANGUAGE_LR.csv',
#  '309636_rfMRI_REST1_LR.csv',
#  '690152_rfMRI_REST1_LR.csv',
#  '585862_tfMRI_LANGUAGE_LR.csv',
#  '213522_rfMRI_REST1_LR.csv',
#  '214221_rfMRI_REST1_LR.csv',
#  '114924_tfMRI_MOTOR_LR.csv',
#  '615744_tfMRI_MOTOR_LR.csv',
#  '189349_rfMRI_REST1_LR.csv',
#  '156233_tfMRI_MOTOR_LR.csv',
#  '130316_rfMRI_REST1_LR.csv',
#  '322224_rfMRI_REST1_LR.csv',
#  '346137_rfMRI_REST1_LR.csv',
#  '187143_tfMRI_MOTOR_LR.csv',
#  '212015_tfMRI_LANGUAGE_LR.csv',
#  '634748_rfMRI_REST1_LR.csv',
#  '151728_tfMRI_LANGUAGE_LR.csv',
#  '572045_tfMRI_MOTOR_LR.csv',
#  '101006_tfMRI_MOTOR_LR.csv',
#  '118528_tfMRI_MOTOR_LR.csv',
#  '562345_tfMRI_MOTOR_LR.csv',
#  '111514_rfMRI_REST1_LR.csv',
#  '173940_tfMRI_MOTOR_LR.csv',
#  '597869_tfMRI_LANGUAGE_LR.csv',
#  '162329_rfMRI_REST1_LR.csv',
#  '645551_tfMRI_MOTOR_LR.csv',
#  '545345_rfMRI_REST1_LR.csv',
#  '108525_tfMRI_MOTOR_LR.csv',
#  '679568_rfMRI_REST1_LR.csv',
#  '173435_tfMRI_LANGUAGE_LR.csv',
#  '128632_rfMRI_REST1_LR.csv',
#  '136227_tfMRI_LANGUAGE_LR.csv',
#  '236130_tfMRI_MOTOR_LR.csv',
#  '239136_tfMRI_MOTOR_LR.csv',
#  '106016_tfMRI_LANGUAGE_LR.csv',
#  '213017_tfMRI_MOTOR_LR.csv',
#  '519647_tfMRI_MOTOR_LR.csv',
#  '237334_tfMRI_MOTOR_LR.csv',
#  '133827_tfMRI_LANGUAGE_LR.csv',
#  '320826_rfMRI_REST1_LR.csv',
#  '333330_tfMRI_LANGUAGE_LR.csv',
#  '203923_rfMRI_REST1_LR.csv',
#  '160830_tfMRI_LANGUAGE_LR.csv',
#  '154431_rfMRI_REST1_LR.csv',
#  '196952_tfMRI_LANGUAGE_LR.csv',
#  '138332_tfMRI_MOTOR_LR.csv',
#  '744553_tfMRI_MOTOR_LR.csv',
#  '129028_tfMRI_LANGUAGE_LR.csv',
#  '463040_rfMRI_REST1_LR.csv',
#  '219231_rfMRI_REST1_LR.csv',
#  '118528_rfMRI_REST1_LR.csv',
#  '101309_rfMRI_REST1_LR.csv',
#  '153934_tfMRI_LANGUAGE_LR.csv',
#  '185038_tfMRI_LANGUAGE_LR.csv',
#  '380036_tfMRI_LANGUAGE_LR.csv',
#  '176845_tfMRI_MOTOR_LR.csv',
#  '180937_tfMRI_MOTOR_LR.csv',
#  '177241_rfMRI_REST1_LR.csv',
#  '169545_tfMRI_LANGUAGE_LR.csv',
#  '558657_tfMRI_LANGUAGE_LR.csv',
#  '168139_tfMRI_MOTOR_LR.csv',
#  '113316_tfMRI_LANGUAGE_LR.csv',
#  '132017_tfMRI_MOTOR_LR.csv',
#  '587664_rfMRI_REST1_LR.csv',
#  '192540_tfMRI_LANGUAGE_LR.csv',
#  '198855_tfMRI_MOTOR_LR.csv',
#  '690152_tfMRI_MOTOR_LR.csv',
#  '139839_tfMRI_MOTOR_LR.csv',
#  '167440_tfMRI_MOTOR_LR.csv',
#  '517239_tfMRI_MOTOR_LR.csv',
#  '169949_tfMRI_MOTOR_LR.csv',
#  '126628_tfMRI_LANGUAGE_LR.csv',
#  '715041_tfMRI_LANGUAGE_LR.csv',
#  '135225_tfMRI_LANGUAGE_LR.csv',
#  '114217_rfMRI_REST1_LR.csv',
#  '680957_tfMRI_MOTOR_LR.csv',
#  '125222_tfMRI_MOTOR_LR.csv',
#  '209834_tfMRI_LANGUAGE_LR.csv',
#  '105216_tfMRI_MOTOR_LR.csv',
#  '397861_tfMRI_MOTOR_LR.csv',
#  '121921_tfMRI_LANGUAGE_LR.csv',
#  '130821_rfMRI_REST1_LR.csv',
#  '285345_rfMRI_REST1_LR.csv',
#  '680957_rfMRI_REST1_LR.csv',
#  '116221_tfMRI_LANGUAGE_LR.csv',
#  '680452_rfMRI_REST1_LR.csv',
#  '566454_rfMRI_REST1_LR.csv',
#  '135225_rfMRI_REST1_LR.csv',
#  '192641_tfMRI_LANGUAGE_LR.csv',
#  '412528_tfMRI_MOTOR_LR.csv',
#  '118831_rfMRI_REST1_LR.csv',
#  '101915_tfMRI_LANGUAGE_LR.csv',
#  '623844_tfMRI_MOTOR_LR.csv',
#  '146129_tfMRI_LANGUAGE_LR.csv',
#  '206222_rfMRI_REST1_LR.csv',
#  '361941_tfMRI_MOTOR_LR.csv',
#  '283543_tfMRI_MOTOR_LR.csv',
#  '211821_tfMRI_LANGUAGE_LR.csv',
#  '164030_rfMRI_REST1_LR.csv',
#  '129634_tfMRI_LANGUAGE_LR.csv',
#  '523032_rfMRI_REST1_LR.csv',
#  '378857_rfMRI_REST1_LR.csv',
#  '255740_tfMRI_LANGUAGE_LR.csv',
#  '141422_tfMRI_LANGUAGE_LR.csv',
#  '156334_tfMRI_MOTOR_LR.csv',
#  '103111_rfMRI_REST1_LR.csv',
#  '645551_rfMRI_REST1_LR.csv',
#  '162026_tfMRI_LANGUAGE_LR.csv',
#  '250427_rfMRI_REST1_LR.csv',
#  '126325_tfMRI_LANGUAGE_LR.csv',
#  '469961_rfMRI_REST1_LR.csv',
#  '108323_tfMRI_LANGUAGE_LR.csv',
#  '663755_rfMRI_REST1_LR.csv',
#  '693764_tfMRI_MOTOR_LR.csv',
#  '192237_tfMRI_LANGUAGE_LR.csv',
#  '214221_tfMRI_MOTOR_LR.csv',
#  '115320_tfMRI_MOTOR_LR.csv',
#  '274542_tfMRI_MOTOR_LR.csv',
#  '182436_tfMRI_MOTOR_LR.csv',
#  '123521_tfMRI_MOTOR_LR.csv',
#  '111009_rfMRI_REST1_LR.csv',
#  '131419_tfMRI_MOTOR_LR.csv',
#  '473952_tfMRI_LANGUAGE_LR.csv',
#  '158338_rfMRI_REST1_LR.csv',
#  '680957_tfMRI_LANGUAGE_LR.csv',
#  '172332_tfMRI_LANGUAGE_LR.csv',
#  '169343_tfMRI_MOTOR_LR.csv',
#  '171532_tfMRI_LANGUAGE_LR.csv',
#  '309636_tfMRI_LANGUAGE_LR.csv',
#  '183741_tfMRI_MOTOR_LR.csv',
#  '568963_rfMRI_REST1_LR.csv',
#  '692964_tfMRI_MOTOR_LR.csv',
#  '140925_tfMRI_MOTOR_LR.csv',
#  '197550_rfMRI_REST1_LR.csv',
#  '725751_tfMRI_MOTOR_LR.csv',
#  '250932_rfMRI_REST1_LR.csv',
#  '151526_rfMRI_REST1_LR.csv',
#  '177645_rfMRI_REST1_LR.csv',
#  '200513_tfMRI_MOTOR_LR.csv',
#  '120212_rfMRI_REST1_LR.csv',
#  '172635_tfMRI_LANGUAGE_LR.csv',
#  '199958_tfMRI_MOTOR_LR.csv',
#  '547046_rfMRI_REST1_LR.csv',
#  '128935_tfMRI_LANGUAGE_LR.csv',
#  '192540_rfMRI_REST1_LR.csv',
#  '192641_tfMRI_MOTOR_LR.csv',
#  '119126_rfMRI_REST1_LR.csv',
#  '202820_rfMRI_REST1_LR.csv',
#  '715647_tfMRI_LANGUAGE_LR.csv',
#  '339847_tfMRI_MOTOR_LR.csv',
#  '204521_rfMRI_REST1_LR.csv',
#  '314225_rfMRI_REST1_LR.csv',
#  '140925_tfMRI_LANGUAGE_LR.csv',
#  '341834_rfMRI_REST1_LR.csv',
#  '111009_tfMRI_LANGUAGE_LR.csv',
#  '356948_rfMRI_REST1_LR.csv',
#  '136833_tfMRI_LANGUAGE_LR.csv',
#  '208327_rfMRI_REST1_LR.csv',
#  '449753_tfMRI_MOTOR_LR.csv',
#  '627549_rfMRI_REST1_LR.csv',
#  '113619_rfMRI_REST1_LR.csv',
#  '468050_tfMRI_MOTOR_LR.csv',
#  '102614_rfMRI_REST1_LR.csv',
#  '429040_tfMRI_LANGUAGE_LR.csv',
#  '394956_tfMRI_MOTOR_LR.csv',
#  '125525_tfMRI_MOTOR_LR.csv',
#  '135730_rfMRI_REST1_LR.csv',
#  '180937_rfMRI_REST1_LR.csv',
#  '329440_tfMRI_LANGUAGE_LR.csv',
#  '555348_rfMRI_REST1_LR.csv',
#  '635245_tfMRI_LANGUAGE_LR.csv',
#  '195445_rfMRI_REST1_LR.csv',
#  '585256_tfMRI_MOTOR_LR.csv',
#  '213017_tfMRI_LANGUAGE_LR.csv',
#  '151021_rfMRI_REST1_LR.csv',
#  '159441_tfMRI_LANGUAGE_LR.csv',
#  '151627_tfMRI_LANGUAGE_LR.csv',
#  '567052_tfMRI_LANGUAGE_LR.csv',
#  '617748_rfMRI_REST1_LR.csv',
#  '211417_tfMRI_MOTOR_LR.csv',
#  '129634_tfMRI_MOTOR_LR.csv',
#  '524135_rfMRI_REST1_LR.csv',
#  '148840_tfMRI_MOTOR_LR.csv',
#  '115724_tfMRI_LANGUAGE_LR.csv',
#  '173839_rfMRI_REST1_LR.csv',
#  '298051_tfMRI_MOTOR_LR.csv',
#  '155938_rfMRI_REST1_LR.csv',
#  '412528_tfMRI_LANGUAGE_LR.csv',
#  '342129_rfMRI_REST1_LR.csv',
#  '107725_tfMRI_MOTOR_LR.csv',
#  '690152_tfMRI_LANGUAGE_LR.csv',
#  '191841_tfMRI_LANGUAGE_LR.csv',
#  '120515_tfMRI_LANGUAGE_LR.csv',
#  '376247_rfMRI_REST1_LR.csv',
#  '281135_tfMRI_MOTOR_LR.csv',
#  '198350_tfMRI_MOTOR_LR.csv',
#  '205220_rfMRI_REST1_LR.csv',
#  '393550_rfMRI_REST1_LR.csv',
#  '168240_tfMRI_MOTOR_LR.csv',
#  '541640_tfMRI_LANGUAGE_LR.csv',
#  '378756_tfMRI_MOTOR_LR.csv',
#  '715950_tfMRI_LANGUAGE_LR.csv',
#  '131924_tfMRI_LANGUAGE_LR.csv',
#  '280739_rfMRI_REST1_LR.csv',
#  '163129_tfMRI_LANGUAGE_LR.csv',
#  '115017_rfMRI_REST1_LR.csv',
#  '181232_tfMRI_MOTOR_LR.csv',
#  '561242_tfMRI_MOTOR_LR.csv',
#  '566454_tfMRI_MOTOR_LR.csv',
#  '692964_tfMRI_LANGUAGE_LR.csv',
#  '170934_tfMRI_LANGUAGE_LR.csv',
#  '704238_tfMRI_MOTOR_LR.csv',
#  '615744_rfMRI_REST1_LR.csv',
#  '164131_rfMRI_REST1_LR.csv',
#  '167743_rfMRI_REST1_LR.csv',
#  '204218_tfMRI_MOTOR_LR.csv',
#  '638049_rfMRI_REST1_LR.csv',
#  '548250_rfMRI_REST1_LR.csv',
#  '679770_tfMRI_MOTOR_LR.csv',
#  '616645_tfMRI_LANGUAGE_LR.csv',
#  '695768_tfMRI_LANGUAGE_LR.csv',
#  '175035_rfMRI_REST1_LR.csv',
#  '181636_tfMRI_LANGUAGE_LR.csv',
#  '522434_tfMRI_MOTOR_LR.csv',
#  '545345_tfMRI_LANGUAGE_LR.csv',
#  '185846_tfMRI_LANGUAGE_LR.csv',
#  '197550_tfMRI_MOTOR_LR.csv',
#  '102513_rfMRI_REST1_LR.csv',
#  '119025_tfMRI_MOTOR_LR.csv',
#  '163836_tfMRI_LANGUAGE_LR.csv',
#  '153934_rfMRI_REST1_LR.csv',
#  '701535_rfMRI_REST1_LR.csv',
#  '654754_tfMRI_MOTOR_LR.csv',
#  '485757_tfMRI_LANGUAGE_LR.csv',
#  '149337_tfMRI_LANGUAGE_LR.csv',
#  '304727_tfMRI_MOTOR_LR.csv',
#  '588565_tfMRI_MOTOR_LR.csv',
#  '146937_tfMRI_LANGUAGE_LR.csv',
#  '115825_rfMRI_REST1_LR.csv',
#  '360030_tfMRI_MOTOR_LR.csv',
#  '214726_tfMRI_LANGUAGE_LR.csv',
#  '214423_tfMRI_LANGUAGE_LR.csv',
#  '387959_tfMRI_MOTOR_LR.csv',
#  '558657_tfMRI_MOTOR_LR.csv',
#  '102311_tfMRI_MOTOR_LR.csv',
#  '199150_tfMRI_MOTOR_LR.csv',
#  '580650_tfMRI_MOTOR_LR.csv',
#  '510326_tfMRI_LANGUAGE_LR.csv',
#  '148032_tfMRI_MOTOR_LR.csv',
#  '163836_rfMRI_REST1_LR.csv',
#  '201414_rfMRI_REST1_LR.csv',
#  '486759_rfMRI_REST1_LR.csv',
#  '580650_tfMRI_LANGUAGE_LR.csv',
#  '213522_tfMRI_LANGUAGE_LR.csv',
#  '257946_rfMRI_REST1_LR.csv',
#  '660951_tfMRI_MOTOR_LR.csv',
#  '134829_tfMRI_MOTOR_LR.csv',
#  '151526_tfMRI_LANGUAGE_LR.csv',
#  '245333_tfMRI_MOTOR_LR.csv',
#  '185341_rfMRI_REST1_LR.csv',
#  '175439_tfMRI_MOTOR_LR.csv',
#  '679568_tfMRI_MOTOR_LR.csv',
#  '206323_rfMRI_REST1_LR.csv',
#  '685058_tfMRI_MOTOR_LR.csv',
#  '158540_tfMRI_MOTOR_LR.csv',
#  '183337_tfMRI_LANGUAGE_LR.csv',
#  '102513_tfMRI_LANGUAGE_LR.csv',
#  '129331_tfMRI_MOTOR_LR.csv',
#  '516742_rfMRI_REST1_LR.csv',
#  '145834_tfMRI_LANGUAGE_LR.csv',
#  '140117_tfMRI_MOTOR_LR.csv',
#  '211922_tfMRI_MOTOR_LR.csv',
#  '675661_tfMRI_MOTOR_LR.csv',
#  '148032_tfMRI_LANGUAGE_LR.csv',
#  '135124_tfMRI_MOTOR_LR.csv',
#  '141826_tfMRI_LANGUAGE_LR.csv',
#  '525541_tfMRI_MOTOR_LR.csv',
#  '130114_tfMRI_LANGUAGE_LR.csv',
#  '159946_tfMRI_MOTOR_LR.csv',
#  '193239_tfMRI_LANGUAGE_LR.csv',
#  '293748_tfMRI_LANGUAGE_LR.csv',
#  '361234_tfMRI_LANGUAGE_LR.csv',
#  '169545_tfMRI_MOTOR_LR.csv',
#  '192237_tfMRI_MOTOR_LR.csv',
#  '314225_tfMRI_MOTOR_LR.csv',
#  '627852_tfMRI_MOTOR_LR.csv',
#  '151728_tfMRI_MOTOR_LR.csv',
#  '293748_rfMRI_REST1_LR.csv',
#  '156031_rfMRI_REST1_LR.csv',
#  '150928_tfMRI_MOTOR_LR.csv',
#  '136126_rfMRI_REST1_LR.csv',
#  '141422_rfMRI_REST1_LR.csv',
#  '433839_rfMRI_REST1_LR.csv',
#  '130316_tfMRI_MOTOR_LR.csv',
#  '150524_tfMRI_MOTOR_LR.csv',
#  '255740_rfMRI_REST1_LR.csv',
#  '559457_tfMRI_LANGUAGE_LR.csv',
#  '453441_tfMRI_LANGUAGE_LR.csv',
#  '199958_tfMRI_LANGUAGE_LR.csv',
#  '579867_tfMRI_MOTOR_LR.csv',
#  '316633_rfMRI_REST1_LR.csv',
#  '102109_rfMRI_REST1_LR.csv',
#  '311320_tfMRI_MOTOR_LR.csv',
#  '156637_tfMRI_MOTOR_LR.csv',
#  '200917_tfMRI_LANGUAGE_LR.csv',
#  '117930_rfMRI_REST1_LR.csv',
#  '705341_tfMRI_LANGUAGE_LR.csv',
#  '581450_tfMRI_LANGUAGE_LR.csv',
#  '298455_tfMRI_LANGUAGE_LR.csv',
#  '479762_tfMRI_LANGUAGE_LR.csv',
#  '169444_tfMRI_MOTOR_LR.csv',
#  '355239_tfMRI_MOTOR_LR.csv',
#  '177645_tfMRI_MOTOR_LR.csv',
#  '316633_tfMRI_LANGUAGE_LR.csv',
#  '604537_rfMRI_REST1_LR.csv',
#  '734045_rfMRI_REST1_LR.csv',
#  '146836_rfMRI_REST1_LR.csv',
#  '433839_tfMRI_MOTOR_LR.csv',
#  '700634_rfMRI_REST1_LR.csv',
#  '580751_rfMRI_REST1_LR.csv',
#  '320826_tfMRI_MOTOR_LR.csv',
#  '304727_tfMRI_LANGUAGE_LR.csv',
#  '106319_rfMRI_REST1_LR.csv',
#  '141826_tfMRI_MOTOR_LR.csv',
#  '152427_tfMRI_LANGUAGE_LR.csv',
#  '183741_tfMRI_LANGUAGE_LR.csv',
#  '140925_rfMRI_REST1_LR.csv',
#  '156031_tfMRI_LANGUAGE_LR.csv',
#  '552241_tfMRI_MOTOR_LR.csv',
#  '204319_tfMRI_LANGUAGE_LR.csv',
#  '122418_rfMRI_REST1_LR.csv',
#  '131217_rfMRI_REST1_LR.csv',
#  '142828_tfMRI_MOTOR_LR.csv',
#  '545345_tfMRI_MOTOR_LR.csv',
#  '151627_tfMRI_MOTOR_LR.csv',
#  '401422_tfMRI_MOTOR_LR.csv',
#  '137128_tfMRI_MOTOR_LR.csv',
#  '100408_tfMRI_LANGUAGE_LR.csv',
#  '205725_tfMRI_LANGUAGE_LR.csv',
#  '143224_tfMRI_LANGUAGE_LR.csv',
#  '499566_tfMRI_LANGUAGE_LR.csv',
#  '111009_tfMRI_MOTOR_LR.csv',
#  '270332_tfMRI_MOTOR_LR.csv',
#  '175136_tfMRI_MOTOR_LR.csv',
#  '137027_tfMRI_LANGUAGE_LR.csv',
#  '580751_tfMRI_MOTOR_LR.csv',
#  '205725_rfMRI_REST1_LR.csv',
#  '162228_tfMRI_MOTOR_LR.csv',
#  '103818_tfMRI_MOTOR_LR.csv',
#  '195445_tfMRI_MOTOR_LR.csv',
#  '715950_rfMRI_REST1_LR.csv',
#  '115219_tfMRI_LANGUAGE_LR.csv',
#  '346137_tfMRI_MOTOR_LR.csv',
#  '171330_tfMRI_MOTOR_LR.csv',
#  '555954_tfMRI_MOTOR_LR.csv',
#  '702133_tfMRI_MOTOR_LR.csv',
#  '214524_rfMRI_REST1_LR.csv',
#  '436845_tfMRI_MOTOR_LR.csv',
#  '132017_rfMRI_REST1_LR.csv',
#  '144832_rfMRI_REST1_LR.csv',
#  '129331_rfMRI_REST1_LR.csv',
#  '523032_tfMRI_LANGUAGE_LR.csv',
#  '158136_tfMRI_MOTOR_LR.csv',
#  '214524_tfMRI_MOTOR_LR.csv',
#  '562345_rfMRI_REST1_LR.csv',
#  '135528_tfMRI_MOTOR_LR.csv',
#  '133019_rfMRI_REST1_LR.csv',
#  '198249_tfMRI_MOTOR_LR.csv',
#  '424939_tfMRI_MOTOR_LR.csv',
#  '614439_tfMRI_LANGUAGE_LR.csv',
#  '151425_tfMRI_MOTOR_LR.csv',
#  '654552_rfMRI_REST1_LR.csv',
#  '154532_rfMRI_REST1_LR.csv',
#  '693764_rfMRI_REST1_LR.csv',
#  '105115_rfMRI_REST1_LR.csv',
#  '307127_rfMRI_REST1_LR.csv',
#  '165032_tfMRI_MOTOR_LR.csv',
#  '176542_tfMRI_MOTOR_LR.csv',
#  '581450_tfMRI_MOTOR_LR.csv',
#  '119126_tfMRI_MOTOR_LR.csv',
#  '124826_rfMRI_REST1_LR.csv',
#  '120212_tfMRI_MOTOR_LR.csv',
#  '671855_tfMRI_MOTOR_LR.csv',
#  '729254_tfMRI_LANGUAGE_LR.csv',
#  '114419_tfMRI_MOTOR_LR.csv',
#  '150928_tfMRI_LANGUAGE_LR.csv',
#  '346945_tfMRI_MOTOR_LR.csv',
#  '436239_tfMRI_LANGUAGE_LR.csv',
#  '175338_tfMRI_LANGUAGE_LR.csv',
#  '154936_tfMRI_MOTOR_LR.csv',
#  '171532_rfMRI_REST1_LR.csv',
#  '558960_tfMRI_MOTOR_LR.csv',
#  '191033_tfMRI_MOTOR_LR.csv',
#  '172332_tfMRI_MOTOR_LR.csv',
#  '191235_rfMRI_REST1_LR.csv',
#  '163129_tfMRI_MOTOR_LR.csv',
#  '199453_rfMRI_REST1_LR.csv',
#  '101006_tfMRI_LANGUAGE_LR.csv',
#  '161731_tfMRI_MOTOR_LR.csv',
#  '159946_rfMRI_REST1_LR.csv',
#  '122620_rfMRI_REST1_LR.csv',
#  '121416_tfMRI_LANGUAGE_LR.csv',
#  '143830_rfMRI_REST1_LR.csv',
#  '448347_tfMRI_LANGUAGE_LR.csv',
#  '111211_rfMRI_REST1_LR.csv',
#  '530635_tfMRI_MOTOR_LR.csv',
#  '106824_rfMRI_REST1_LR.csv',
#  '137128_rfMRI_REST1_LR.csv',
#  '202820_tfMRI_MOTOR_LR.csv',
#  '153631_tfMRI_LANGUAGE_LR.csv',
#  '131924_rfMRI_REST1_LR.csv',
#  '196851_rfMRI_REST1_LR.csv',
#  '141119_tfMRI_MOTOR_LR.csv',
#  '168240_rfMRI_REST1_LR.csv',
#  '127630_rfMRI_REST1_LR.csv',
#  '571144_rfMRI_REST1_LR.csv',
#  '307127_tfMRI_LANGUAGE_LR.csv',
#  '175742_tfMRI_LANGUAGE_LR.csv',
#  '200210_tfMRI_LANGUAGE_LR.csv',
#  '686969_tfMRI_LANGUAGE_LR.csv',
#  '178950_tfMRI_LANGUAGE_LR.csv',
#  '558960_tfMRI_LANGUAGE_LR.csv',
#  '156334_tfMRI_LANGUAGE_LR.csv',
#  '139839_rfMRI_REST1_LR.csv',
#  '149337_tfMRI_MOTOR_LR.csv',
#  '101410_tfMRI_LANGUAGE_LR.csv',
#  '171532_tfMRI_MOTOR_LR.csv',
#  '645551_tfMRI_LANGUAGE_LR.csv',
#  '214423_rfMRI_REST1_LR.csv',
#  '461743_tfMRI_LANGUAGE_LR.csv',
#  '200109_rfMRI_REST1_LR.csv',
#  '196952_tfMRI_MOTOR_LR.csv',
#  '657659_tfMRI_MOTOR_LR.csv',
#  '548250_tfMRI_MOTOR_LR.csv',
#  '239944_rfMRI_REST1_LR.csv',
#  '178748_tfMRI_LANGUAGE_LR.csv',
#  '161832_tfMRI_LANGUAGE_LR.csv',
#  '117324_tfMRI_MOTOR_LR.csv',
#  '268749_rfMRI_REST1_LR.csv',
#  '664757_tfMRI_LANGUAGE_LR.csv',
#  '622236_tfMRI_MOTOR_LR.csv',
#  '210112_tfMRI_LANGUAGE_LR.csv',
#  '121618_tfMRI_LANGUAGE_LR.csv',
#  '201414_tfMRI_LANGUAGE_LR.csv',
#  '175035_tfMRI_MOTOR_LR.csv',
#  '109830_rfMRI_REST1_LR.csv',
#  '163331_rfMRI_REST1_LR.csv',
#  '189349_tfMRI_LANGUAGE_LR.csv',
#  '587664_tfMRI_LANGUAGE_LR.csv',
#  '352132_tfMRI_MOTOR_LR.csv',
#  '485757_rfMRI_REST1_LR.csv',
#  '707749_tfMRI_LANGUAGE_LR.csv',
#  '110613_rfMRI_REST1_LR.csv',
#  '519950_tfMRI_MOTOR_LR.csv',
#  '154431_tfMRI_LANGUAGE_LR.csv',
#  '263436_tfMRI_MOTOR_LR.csv',
#  '353740_tfMRI_MOTOR_LR.csv',
#  '137229_tfMRI_LANGUAGE_LR.csv',
#  '146432_tfMRI_MOTOR_LR.csv',
#  '176239_tfMRI_LANGUAGE_LR.csv',
#  '191841_tfMRI_MOTOR_LR.csv',
#  '119025_tfMRI_LANGUAGE_LR.csv',
#  '162026_rfMRI_REST1_LR.csv',
#  '285446_tfMRI_LANGUAGE_LR.csv',
#  '365343_tfMRI_MOTOR_LR.csv',
#  '122822_tfMRI_LANGUAGE_LR.csv',
#  '530635_rfMRI_REST1_LR.csv',
#  '178950_rfMRI_REST1_LR.csv',
#  '138130_tfMRI_MOTOR_LR.csv',
#  '211619_tfMRI_MOTOR_LR.csv',
#  '199958_rfMRI_REST1_LR.csv',
#  '176845_tfMRI_LANGUAGE_LR.csv',
#  '667056_tfMRI_LANGUAGE_LR.csv',
#  '365343_rfMRI_REST1_LR.csv',
#  '193239_rfMRI_REST1_LR.csv',
#  '151425_rfMRI_REST1_LR.csv',
#  '529549_tfMRI_LANGUAGE_LR.csv',
#  '112112_rfMRI_REST1_LR.csv',
#  '146735_rfMRI_REST1_LR.csv',
#  '540436_tfMRI_MOTOR_LR.csv',
#  '201111_tfMRI_LANGUAGE_LR.csv',
#  '103515_tfMRI_LANGUAGE_LR.csv',
#  '152427_tfMRI_MOTOR_LR.csv',
#  '103111_tfMRI_LANGUAGE_LR.csv',
#  '180230_rfMRI_REST1_LR.csv',
#  '115219_rfMRI_REST1_LR.csv',
#  '731140_tfMRI_MOTOR_LR.csv',
#  '154330_tfMRI_MOTOR_LR.csv',
#  '349244_rfMRI_REST1_LR.csv',
#  '102008_tfMRI_MOTOR_LR.csv',
#  '512835_tfMRI_MOTOR_LR.csv',
#  '187345_rfMRI_REST1_LR.csv',
#  '298455_tfMRI_MOTOR_LR.csv',
#  '127226_rfMRI_REST1_LR.csv',
#  '200210_tfMRI_MOTOR_LR.csv',
#  '209329_tfMRI_LANGUAGE_LR.csv',
#  '701535_tfMRI_MOTOR_LR.csv',
#  '617748_tfMRI_LANGUAGE_LR.csv',
#  '705341_tfMRI_MOTOR_LR.csv',
#  '173334_tfMRI_LANGUAGE_LR.csv',
#  '613538_tfMRI_MOTOR_LR.csv',
#  '168745_rfMRI_REST1_LR.csv',
#  '158338_tfMRI_MOTOR_LR.csv',
#  '174841_tfMRI_LANGUAGE_LR.csv',
#  '368753_rfMRI_REST1_LR.csv',
#  ...]

# %%
class FMRIConnectivityDataset(Dataset):
    def __init__(self, data_directory, ids, transform=None):
        self.transform = transform
        self.data = [] 

        for subject_id in ids:
            rest_file_path = os.path.join(data_directory, f"{subject_id}_rfMRI_REST1_LR.csv")
            motor_file_path = os.path.join(data_directory, f"{subject_id}_tfMRI_MOTOR_LR.csv")

            if os.path.exists(rest_file_path) and os.path.exists(motor_file_path):
                rest_data = pd.read_csv(rest_file_path)
                motor_data = pd.read_csv(motor_file_path)

                self.data.append((subject_id, rest_data.values, motor_data.values))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        subject_id, rest_fMRI_matrix, motor_task_fMRI_matrix = self.data[idx]

        data_dict = {
            "subject_id": subject_id,
            "rest_fMRI_data": torch.FloatTensor(rest_fMRI_matrix[np.newaxis,:,:]),
            "motor_task_fMRI_data": torch.FloatTensor(motor_task_fMRI_matrix[np.newaxis,:,:])
        }

        return data_dict

# %%
data_directory  = '/beegfs/home/ruslan.kalimullin/Image_to_image/data_77'

file_names = [f for f in os.listdir(data_directory) if f.endswith(".csv")]

file_ids = list(set([file.split('_')[0] for file in file_names]))  

train_ratio = 0.8
test_ratio = 0.2

train_ids, remaining_ids = train_test_split(file_ids, test_size=test_ratio, random_state=1380)
test_ids = remaining_ids 

train_dataset = FMRIConnectivityDataset(data_directory, train_ids)
test_dataset = FMRIConnectivityDataset(data_directory, test_ids)

batch_size = 1
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_data_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Initialize generator

# %%
# custom weights initialization called on generator and discriminator        
def weights_init(net, init_type='normal', scaling=0.02):
    """Initialize network weights.
    Parameters:
        net (network)   -- network to be initialized
        init_type (str) -- the name of an initialization method: normal | xavier | kaiming | orthogonal
        init_gain (float)    -- scaling factor for normal, xavier and orthogonal.
    We use 'normal' in the original pix2pix and CycleGAN paper. But xavier and kaiming might
    work better for some applications. Feel free to try yourself.
    """
    def init_func(m):  # define the initialization function
        classname = m.__class__.__name__
        if hasattr(m, 'weight') and (classname.find('Conv')) != -1:
            torch.nn.init.normal_(m.weight.data, 0.0, scaling)
        elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
            torch.nn.init.normal_(m.weight.data, 1.0, scaling)
            torch.nn.init.constant_(m.bias.data, 0.0)

    print('initialize network with %s' % init_type)
    net.apply(init_func)  # apply the initialization function <init_func>

# %%
def get_norm_layer():
    """Return a normalization layer
       For BatchNorm, we use learnable affine parameters and track running statistics (mean/stddev).
    """
    norm_type = 'batch'
    if norm_type == 'batch':
        norm_layer = functools.partial(nn.BatchNorm2d, affine=True, track_running_stats=True)
    return norm_layer

# %%
class UnetGenerator(nn.Module):
    """Create a Unet-based generator"""

    def __init__(self, input_nc, output_nc, nf=64, norm_layer=nn.BatchNorm2d, use_dropout=False):
        """Construct a Unet generator
        Parameters:
            input_nc (int)  -- the number of channels in input images
            output_nc (int) -- the number of channels in output images
            num_downs (int) -- the number of downsamplings in UNet. For example, # if |num_downs| == 7,
                                image of size 128x128 will become of size 1x1 # at the bottleneck
            nf (int)       -- the number of filters in the last conv layer
            norm_layer      -- normalization layer
        We construct the U-Net from the innermost layer to the outermost layer.
        It is a recursive process.
        """
        super(UnetGenerator, self).__init__()
        # construct unet structure
        unet_block = UnetSkipConnectionBlock(nf * 8, nf * 8, input_nc=None, submodule=None, norm_layer=norm_layer, innermost=True)  # add the innermost layer
        
        # add intermediate layers with ngf * 8 filters
        unet_block = UnetSkipConnectionBlock(nf * 8, nf * 8, input_nc=None, submodule=unet_block, norm_layer=norm_layer, use_dropout=use_dropout)
        unet_block = UnetSkipConnectionBlock(nf * 8, nf * 8, input_nc=None, submodule=unet_block, norm_layer=norm_layer, use_dropout=use_dropout)
        unet_block = UnetSkipConnectionBlock(nf * 8, nf * 8, input_nc=None, submodule=unet_block, norm_layer=norm_layer, use_dropout=use_dropout)
        
        # gradually reduce the number of filters from nf * 8 to nf
        unet_block = UnetSkipConnectionBlock(nf * 4, nf * 8, input_nc=None, submodule=unet_block, norm_layer=norm_layer)
        unet_block = UnetSkipConnectionBlock(nf * 2, nf * 4, input_nc=None, submodule=unet_block, norm_layer=norm_layer)
        unet_block = UnetSkipConnectionBlock(nf, nf * 2, input_nc=None, submodule=unet_block, norm_layer=norm_layer)
        self.model = UnetSkipConnectionBlock(output_nc, nf, input_nc=input_nc, submodule=unet_block, outermost=True, norm_layer=norm_layer)  # add the outermost layer

    def forward(self, input):
        """Standard forward"""
        return self.model(input)

# %%
class UnetSkipConnectionBlock(nn.Module):
    """Defines the Unet submodule with skip connection.
        X -------------------identity----------------------
        |-- downsampling -- |submodule| -- upsampling --|
    """

    def __init__(self, outer_nc, inner_nc, input_nc=None,
                 submodule=None, outermost=False, innermost=False, norm_layer=nn.BatchNorm2d, use_dropout=False):
        """Construct a Unet submodule with skip connections.
        Parameters:
            outer_nc (int) -- the number of filters in the outer conv layer
            inner_nc (int) -- the number of filters in the inner conv layer
            input_nc (int) -- the number of channels in input images/features
            submodule (UnetSkipConnectionBlock) -- previously defined submodules
            outermost (bool)    -- if this module is the outermost module
            innermost (bool)    -- if this module is the innermost module
            norm_layer          -- normalization layer
            use_dropout (bool)  -- if use dropout layers.
        """
        super(UnetSkipConnectionBlock, self).__init__()
        self.outermost = outermost
        if input_nc is None:
            input_nc = outer_nc
        downconv = nn.Conv2d(input_nc, inner_nc, kernel_size=4,
                             stride=2, padding=1, bias=False)
        downrelu = nn.LeakyReLU(0.2, True)
        downnorm = norm_layer(inner_nc)
        uprelu = nn.ReLU(True)
        upnorm = norm_layer(outer_nc)

        if outermost:
            upconv = nn.ConvTranspose2d(inner_nc * 2, outer_nc,
                                        kernel_size=4, stride=2,
                                        padding=1)
            down = [downconv]
            up = [uprelu, upconv, nn.Tanh()]
            model = down + [submodule] + up
        elif innermost:
            upconv = nn.ConvTranspose2d(inner_nc, outer_nc,
                                        kernel_size=4, stride=2,
                                        padding=1, bias=False)
            down = [downrelu, downconv]
            up = [uprelu, upconv, upnorm]
            model = down + up
        else:
            upconv = nn.ConvTranspose2d(inner_nc * 2, outer_nc,
                                        kernel_size=4, stride=2,
                                        padding=1, bias=False)
            down = [downrelu, downconv, downnorm]
            up = [uprelu, upconv, upnorm]

            if use_dropout:
                model = down + [submodule] + up + [nn.Dropout(0.5)]
            else:
                model = down + [submodule] + up

        self.model = nn.Sequential(*model)

    def forward(self, x):
        if self.outermost:
            return self.model(x)
        else:   # add skip connections
            return torch.cat([x, self.model(x)], 1)

# %%
norm_layer = get_norm_layer()

# %%
class UnetSkipConnectionBlock(nn.Module):
    def __init__(self, outer_nc, inner_nc, input_nc=None,
                 submodule=None, outermost=False, innermost=False, norm_layer=nn.BatchNorm2d, use_dropout=False):
        super(UnetSkipConnectionBlock, self).__init__()
        self.outermost = outermost
        if input_nc is None:
            input_nc = outer_nc

        downconv = nn.Conv2d(input_nc, inner_nc, kernel_size=3, stride=1, padding=1, bias=False)
        downrelu = nn.LeakyReLU(0.2, True)
        downnorm = norm_layer(inner_nc)

        uprelu = nn.ReLU(True)
        upnorm = norm_layer(outer_nc)

        if outermost:
            # Modify the kernel size for the outermost upconv layer
            upconv = nn.ConvTranspose2d(inner_nc*2, outer_nc,
                                        kernel_size=3, stride=1, padding=1)  # Adjusted kernel_size and stride
            down = [downconv]
            up = [uprelu, upconv, nn.Tanh()]
            model = down + [submodule] + up
        elif innermost:
            upconv = nn.ConvTranspose2d(inner_nc, outer_nc,
                                        kernel_size=3, stride=1,
                                        padding=1, bias=False)
            down = [downrelu, downconv]
            up = [uprelu, upconv, upnorm]
            model = down + up
        else:
            upconv = nn.ConvTranspose2d(inner_nc*2, outer_nc,
                                        kernel_size=3, stride=1,
                                        padding=1, bias=False)
            down = [downrelu, downconv, downnorm]
            up = [uprelu, upconv, upnorm]

            if use_dropout:
                model = down + [submodule] + up + [nn.Dropout(0.5)]
            else:
                model = down + [submodule] + up

        self.model = nn.Sequential(*model)

    def forward(self, x):
        if self.outermost:
            return self.model(x)
        else:   # add skip connections
            model_x = self.model(x)
            print("x size:", x.size())
            print("model_x size:", model_x.size())
            return torch.cat([x, model_x], 1)

# %%
device = 'cuda:0'
norm_layer = get_norm_layer()

# Create the generator
generator = UnetGenerator(1, 1, 64, norm_layer=norm_layer, use_dropout=False)
generator.apply(lambda x: weights_init(x, init_type='normal', scaling=0.02))
generator = generator.to(device)
generator = torch.nn.DataParallel(generator)
inp = torch.ones(1, 1, 77, 77)
inp = inp.to(device)

# Debug 
print("Input Tensor Size:", inp.size())

# Generate output
gen = generator(inp)

# Debug 
print("Generated Tensor Size:", gen.size())
# Out:
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# Input Tensor Size: torch.Size([1, 1, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 256, 77, 77])
# model_x size: torch.Size([1, 256, 77, 77])
# x size: torch.Size([1, 128, 77, 77])
# model_x size: torch.Size([1, 128, 77, 77])
# x size: torch.Size([1, 64, 77, 77])
# model_x size: torch.Size([1, 64, 77, 77])
# Generated Tensor Size: torch.Size([1, 1, 77, 77])

# %% [markdown]
# ## Initialize Discriminator

# %%
class Discriminator(nn.Module):
    """Defines a PatchGAN discriminator"""

    def __init__(self, input_nc, ndf=64, n_layers=3, norm_layer=nn.BatchNorm2d):
        """Construct a PatchGAN discriminator
        Parameters:
            input_nc (int)  -- the number of channels in input images
            ndf (int)       -- the number of filters in the last conv layer
            n_layers (int)  -- the number of conv layers in the discriminator
            norm_layer      -- normalization layer
        """
        super(Discriminator, self).__init__()
        kw = 4
        padw = 1
        sequence = [nn.Conv2d(input_nc, ndf, kernel_size=kw, stride=2, padding=padw), nn.LeakyReLU(0.2, True)]
        nf_mult = 1
        nf_mult_prev = 1
        for n in range(1, n_layers):  # gradually increase the number of filters
            nf_mult_prev = nf_mult
            nf_mult = min(2 ** n, 8)
            sequence += [
                nn.Conv2d(ndf * nf_mult_prev, ndf * nf_mult, kernel_size=kw, stride=2, padding=padw, bias=False),
                norm_layer(ndf * nf_mult),
                nn.LeakyReLU(0.2, True)
            ]

        nf_mult_prev = nf_mult
        nf_mult = min(2 ** n_layers, 8)
        sequence += [
            nn.Conv2d(ndf * nf_mult_prev, ndf * nf_mult, kernel_size=kw, stride=1, padding=padw, bias=False),
            norm_layer(ndf * nf_mult),
            nn.LeakyReLU(0.2, True)
        ]

        sequence += [nn.Conv2d(ndf * nf_mult, 1, kernel_size=kw, stride=1, padding=padw), nn.Sigmoid()]  # output 1 channel prediction map
        self.model = nn.Sequential(*sequence)

    def forward(self, input):
        """Standard forward."""
        return self.model(input)

# %%
discriminator = Discriminator(2, 64, n_layers=3, norm_layer=norm_layer)#.cuda().float()
discriminator.apply(weights_init)
discriminator = torch.nn.DataParallel(discriminator)  # multi-GPUs
# Out:
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal

# %%
adversarial_loss = nn.BCELoss() 
l1_loss = nn.L1Loss()

# %%
def generator_loss(generated_image, target_img, G, real_target):
    gen_loss = adversarial_loss(G, real_target)
    l1_l = l1_loss(generated_image, target_img)
    gen_total_loss = gen_loss + (100 * l1_l)
    #print(gen_loss)
    return gen_total_loss

# %%
def discriminator_loss(output, label):
    disc_loss = adversarial_loss(output, label)
    return disc_loss

# %%
learning_rate = 2e-4 
G_optimizer = optim.Adam(generator.parameters(), lr = learning_rate, betas=(0.9, 0.999))
D_optimizer = optim.Adam(discriminator.parameters(), lr = learning_rate, betas=(0.9, 0.999))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
num_epochs = 2
D_loss_plot, G_loss_plot = [], []
for epoch in range(1, num_epochs+1): 
    D_loss_list, G_loss_list = [], []

    for batch in train_data_loader:
        rest_fMRI_data = batch["rest_fMRI_data"].to(device)
        motor_task_fMRI_data = batch["motor_task_fMRI_data"].to(device)

        D_optimizer.zero_grad()

        generated_image = generator(rest_fMRI_data)

        disc_inp_fake = torch.cat((rest_fMRI_data, generated_image), 1)

        real_target = Variable(torch.ones(rest_fMRI_data.size(0), 1, 77, 77).to(device))
        fake_target = Variable(torch.zeros(rest_fMRI_data.size(0), 1, 77, 77).to(device))

        D_fake = discriminator(disc_inp_fake.detach())
        D_fake_loss = discriminator_loss(D_fake, fake_target)

        disc_inp_real = torch.cat((rest_fMRI_data, motor_task_fMRI_data), 1)
        output = discriminator(disc_inp_real)
        D_real_loss = discriminator_loss(output, real_target)

        D_total_loss = (D_real_loss + D_fake_loss) / 2
        D_loss_list.append(D_total_loss)

        D_total_loss.backward()
        D_optimizer.step()

        G_optimizer.zero_grad()
        fake_gen = torch.cat((rest_fMRI_data, generated_image), 1)
        G = discriminator(fake_gen)
        G_loss = generator_loss(generated_image, motor_task_fMRI_data, G, real_target)                                 
        G_loss_list.append(G_loss)

        G_loss.backward()
        G_optimizer.step()

    print('Epoch: [%d/%d]: D_loss: %.3f, G_loss: %.3f' % (
            (epoch), num_epochs, torch.mean(torch.FloatTensor(D_loss_list)), \
            torch.mean(torch.FloatTensor(G_loss_list))))

    D_loss_plot.append(torch.mean(torch.FloatTensor(D_loss_list)))
    G_loss_plot.append(torch.mean(torch.FloatTensor(G_loss_list)))

#     torch.save(generator.state_dict(), 'torch/training_weights/generator_epoch_%d.pth' % (epoch))
#     torch.save(discriminator.state_dict(), 'torch/training_weights/discriminator_epoch_%d.pth' % (epoch))

#     for batch in val_dl:
#         inputs = batch["rest_fMRI_data"].to(device)
#         generated_output = generator(inputs)
#         save_image(generated_output.data[:10], 'torch/images/sample_%d' % epoch + '.png', nrow=5, normalize=True)
# Out:
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 512, 77, 77])
# model_x size: torch.Size([1, 512, 77, 77])
# x size: torch.Size([1, 256, 77, 77])
# model_x size: torch.Size([1, 256, 77, 77])
# x size: torch.Size([1, 128, 77, 77])
# model_x size: torch.Size([1, 128, 77, 77])
# x size: torch.Size([1, 64, 77, 77])
# model_x size: torch.Size([1, 64, 77, 77])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-cf66486f0cf7> in <module>
#      19
#      20         D_fake = discriminator(disc_inp_fake.detach())
# ---> 21         D_fake_loss = discriminator_loss(D_fake, fake_target)
#      22
#      23         disc_inp_real = torch.cat((rest_fMRI_data, motor_task_fMRI_data), 1)
#
# <ipython-input-47-351ef8e3331d> in discriminator_loss(output, label)
#       1 def discriminator_loss(output, label):
# ----> 2     disc_loss = adversarial_loss(output, label)
#       3     return disc_loss
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     610
#     611     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 612         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     613
#     614
#
# ~/.local/lib/python3.8/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2882         reduction_enum = _Reduction.get_enum(reduction)
#    2883     if target.size() != input.size():
# -> 2884         raise ValueError(
#    2885             "Using a target size ({}) that is different to the input size ({}) is deprecated. "
#    2886             "Please ensure they have the same size.".format(target.size(), input.size())
#
# ValueError: Using a target size (torch.Size([1, 1, 77, 77])) that is different to the input size (torch.Size([1, 1, 7, 7])) is deprecated. Please ensure they have the same size.

# %%
# !nvidia-smi
# Out:
# Fri Nov 10 11:52:08 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti      Off| 00000000:02:00.0 Off |                  N/A |
# | 27%   33C    P8               22W / 260W|   9859MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    564229      C   ...s/data/opt/python-3.6.8/bin/python3     9856MiB |
# +---------------------------------------------------------------------------------------+
